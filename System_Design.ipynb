# %%
System Design  : It is the process of defining the architecture, components, modules,
                 interfaces, and data flow for a system to satisfy specific requirements

# %%
-- Functional requirements define what the system does (its features and behaviors)
-- Non-functional requirements define how the system works (its quality, constraints, and performance)
